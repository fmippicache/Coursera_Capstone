# %% [markdown]
# ## Introduction:
# Since Metro Manila, Philippines is still under lockdown due to the COVID-19 pandemic, more youth are becoming interested in indoor hobbies like journaling and collecting stationery. I want to put up a stationery store that will cater to these Filipino youth with spending power (i.e. those who come from affluent families or have high disposable income).

# %% [markdown]
# ## Business Problem:
# I want to find a good location to place a stationery store which is near my target market in Metro Manila. It should be in an area that doesn't already have too many stationery stores nearby.

# %% [markdown]
# ## Data:
# I will need Foursquare location data on hobby stationery shops and book stores in Metro Manila. This is to see which areas don't have many stationery shops yet.
# I will also need location data on affluent villages within Metro Manila since these will be where those in my target market live. I will use this data to see which areas in Metro Manila might have the most number of potential customers. This data is available online.
